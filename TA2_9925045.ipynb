# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ydata_profiling import ProfileReport
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv("C:/Users/USER/Downloads/WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1133            6.7             0.320         0.44             2.4      0.061
# 1134            7.5             0.310         0.41             2.4      0.065
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_file(r"C:\Users\USER\Documents\python\your_report.html")
# Out:
# ...
# Export report to file: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 44.45it/s]

# %% [markdown]
# there is no duplicate rows or missing values in this dataset

# %% [markdown]
# ## preprocessing

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, Id]
# Index: []

# %% [markdown]
# ## dropping duplicates

# %%
df_1 = df.drop_duplicates()
df_1
#there are no duplicate rows
#df_1 is after dropping duplicates
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ## outliers

# %%
df_1.mean()
# Out:
# fixed acidity             8.311111
# volatile acidity          0.531339
# citric acid               0.268364
# residual sugar            2.532152
# chlorides                 0.086933
# free sulfur dioxide      15.615486
# total sulfur dioxide     45.914698
# density                   0.996730
# pH                        3.311015
# sulphates                 0.657708
# alcohol                  10.442111
# quality                   5.657043
# Id                      804.969379
# dtype: float64

# %%
upper_limit = df_1.mean() + 3 * df_1.std()
upper_limit
# Out:
# fixed acidity             13.553896
# volatile acidity           1.070238
# citric acid                0.858422
# residual sugar             6.599905
# chlorides                  0.228735
# free sulfur dioxide       46.366944
# total sulfur dioxide     144.261089
# density                    1.002506
# pH                         3.781007
# sulphates                  1.168904
# alcohol                   13.688698
# quality                    8.074516
# Id                      2196.960728
# dtype: float64

# %%
lower_limit = df_1.mean() - 3 * df_1.std()
lower_limit
# Out:
# fixed acidity             3.068326
# volatile acidity         -0.007561
# citric acid              -0.321694
# residual sugar           -1.535600
# chlorides                -0.054869
# free sulfur dioxide     -15.135973
# total sulfur dioxide    -52.431693
# density                   0.990955
# pH                        2.841023
# sulphates                 0.146512
# alcohol                   7.195525
# quality                   3.239570
# Id                     -587.021970
# dtype: float64

# %%
df_1.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
temp = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

# %%
for i in temp:
    lower_limit = df_1[i].mean() - 3 * df_1[i].std()
    upper_limit = df_1[i].mean() + 3 * df_1[i].std()
    df_1 = df_1[(df_1[i] < upper_limit) & (df_1[i] > lower_limit)]
df_1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df_2 = df_1[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']]
df_2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ## missing values

# %%
#there is no missing value

# %% [markdown]
# ## standardization

# %%
scaled = MinMaxScaler().fit_transform(df_2)
df_scaled = pd.DataFrame(scaled, columns = list(df_2.columns))

# %%
df_scaled
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         0.292683          0.630435     0.000000        0.194444   0.387755
# 1         0.341463          0.826087     0.000000        0.388889   0.612245
# 2         0.341463          0.695652     0.052632        0.305556   0.551020
# 3         0.756098          0.173913     0.736842        0.194444   0.377551
# 4         0.292683          0.630435     0.000000        0.194444   0.387755
# ..             ...               ...          ...             ...        ...
# 930       0.158537          0.423913     0.171053        0.305556   0.387755
# 931       0.219512          0.543478     0.105263        0.194444   0.306122
# 932       0.146341          0.521739     0.105263        0.222222   0.530612
# 933       0.109756          0.467391     0.131579        0.277778   0.244898
# 934       0.109756          0.570652     0.157895        0.222222   0.377551
#
# ...

# %% [markdown]
# ## data imbalancing

# %%
Y = df_scaled['quality']
X = df_scaled.drop('quality', axis = 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)

# %%
X_train
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 386       0.243902          0.565217     0.026316        0.250000   0.295918
# 624       0.439024          0.434783     0.500000        0.083333   0.591837
# 892       0.268293          0.445652     0.171053        0.222222   0.204082
# 85        0.219512          0.521739     0.236842        0.194444   0.418367
# 812       0.121951          0.423913     0.000000        0.250000   0.265306
# ..             ...               ...          ...             ...        ...
# 835       0.219512          0.597826     0.000000        0.194444   0.428571
# 192       0.719512          0.293478     0.618421        0.166667   0.816327
# 629       0.158537          0.489130     0.368421        0.250000   0.102041
# 559       0.475610          0.782609     0.447368        0.055556   0.122449
# 684       0.329268          0.152174     0.342105        0.222222   0.142857
#
# ...

# %% [markdown]
# ## filter

# %%
X = pd.DataFrame(X_train)
Y = pd.DataFrame(Y_train, columns = ['quality'])
df_train_final = pd.concat([X,Y], axis = 'columns')

# %%
df_train_final
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 386       0.243902          0.565217     0.026316        0.250000   0.295918
# 624       0.439024          0.434783     0.500000        0.083333   0.591837
# 892       0.268293          0.445652     0.171053        0.222222   0.204082
# 85        0.219512          0.521739     0.236842        0.194444   0.418367
# 812       0.121951          0.423913     0.000000        0.250000   0.265306
# ..             ...               ...          ...             ...        ...
# 835       0.219512          0.597826     0.000000        0.194444   0.428571
# 192       0.719512          0.293478     0.618421        0.166667   0.816327
# 629       0.158537          0.489130     0.368421        0.250000   0.102041
# 559       0.475610          0.782609     0.447368        0.055556   0.122449
# 684       0.329268          0.152174     0.342105        0.222222   0.142857
#
# ...

# %%
df_train_final.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.269897     0.685069
# volatile acidity          -0.269897          1.000000    -0.587065
# citric acid                0.685069         -0.587065     1.000000
# residual sugar             0.211842          0.051459     0.179095
# chlorides                  0.243551          0.063401     0.133207
# free sulfur dioxide       -0.156559          0.015473    -0.086228
# total sulfur dioxide      -0.096627          0.137993    -0.025728
# density                    0.649689          0.004400     0.340458
# pH                        -0.707817          0.222803    -0.504513
# sulphates                  0.172918         -0.320816     0.268727
# alcohol                   -0.068278         -0.169817     0.133199
# quality                    0.112313         -0.341118     0.246986
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
abs(df_train_final.corr()['quality'].sort_values(ascending = False)) >= 0.25
# Out:
# quality                  True
# alcohol                  True
# sulphates                True
# citric acid             False
# fixed acidity           False
# residual sugar          False
# free sulfur dioxide     False
# pH                      False
# chlorides               False
# total sulfur dioxide    False
# density                 False
# volatile acidity         True
# Name: quality, dtype: bool
